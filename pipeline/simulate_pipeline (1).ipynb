# %%
import pandas as pd
from google.colab import files
import io

# Step 1: Upload CSV manually
uploaded = files.upload()

# Step 2: Read the uploaded CSV
for fn in uploaded.keys():
    df = pd.read_csv(io.BytesIO(uploaded[fn]))

# Step 3: Preview the first 5 rows
print("🔹 Dataset Preview:")
display(df.head())

# Step 4: Show data summary
print("🔹 Shape of the dataset:", df.shape)
print("🔹 Columns:", df.columns)
df.info()
# Out:
#      <input type="file" id="files-166b19a9-8959-4281-bf01-0b98819c2e91" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-166b19a9-8959-4281-bf01-0b98819c2e91">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Drop rows with missing values
df = df.dropna()

# Filter: Only include delivered shipments (simulate status filter)
if 'shipment_status' in df.columns:
    df_filtered = df[df['shipment_status'].str.lower() == 'delivered']
else:
    df_filtered = df.copy()  # If no such column exists

# Convert date columns to datetime (simulate data type transformation)
if 'order_date' in df.columns:
    df_filtered['order_date'] = pd.to_datetime(df_filtered['order_date'])

# Sort by date (simulate ordering logic)
if 'order_date' in df_filtered.columns:
    df_filtered = df_filtered.sort_values(by='order_date')

# Display cleaned and filtered data
print("🔹 Cleaned & Filtered Data:")
df_filtered.head()
# Out:
# 🔹 Cleaned & Filtered Data:
#    Order_Id     Type Order_Date(DateOrders) Shipping_Date(DateOrders)  \
# 0     75834  Payment             2025-01-01                2025-01-16
# 1     75833    Debit             2025-01-01                2025-01-13
# 2     75832     Cash             2025-01-01                2025-01-13
# 3     75831  Payment             2025-01-01                2025-01-13
# 4     75830  Payment             2025-01-01                2025-01-17
#
#    Days_for_Shipment(scheduled)  Days_for_Shipping(real) Delivery_Status  \
# 0                             2                        5   Late delivery
# 1                             1                        2   Late delivery
# 2                             1                        2   Late delivery
# 3                             1                        2   Late delivery
# 4                             4                        6   Late delivery
#
#    Late_Delivery_Risk   Shipping_Mode  Order_Item_Quantity  \
# ...

# %%
df_filtered.to_csv("cleaned_supply_data.csv", index=False)
files.download("cleaned_supply_data.csv")

# %%
html = df_filtered.to_html()

with open("supply_table.html", "w") as f:
    f.write(html)

files.download("supply_table.html")

# %%
print("✅ Data pipeline simulation complete!")
print(f"Total records after cleaning: {len(df_filtered)}")
# Out:
# ✅ Data pipeline simulation complete!
# Total records after cleaning: 1999
